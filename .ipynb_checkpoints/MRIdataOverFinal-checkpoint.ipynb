# %%
import os

# Define dataset root path
dataset_path = r"C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN"

# Define processed image paths
processed_folder = os.path.join(dataset_path, "Processed_Images")
image_folder = os.path.join(processed_folder, "images")
mask_folder = os.path.join(processed_folder, "masks")

# ✅ Create necessary directories if they don’t exist
os.makedirs(processed_folder, exist_ok=True)
os.makedirs(image_folder, exist_ok=True)
os.makedirs(mask_folder, exist_ok=True)

# ✅ Verify dataset structure
folders = ["TRAIN", "VAL", "TEST"]
for folder in folders:
    folder_path = os.path.join(dataset_path, folder)
    if os.path.exists(folder_path):
        print(f"✅ Found: {folder}")
    else:
        print(f"❌ Missing: {folder}")

print("✅ Dataset structure verified. Now ready for image processing!")
# Out:
# ✅ Found: TRAIN
# ✅ Found: VAL
# ✅ Found: TEST
# ✅ Dataset structure verified. Now ready for image processing!

# %% [markdown]
#  Load Original Images

# %%
import os
import numpy as np
import cv2
import json
from tensorflow.keras.preprocessing.image import save_img

# ✅ Define dataset directories
dataset_path = r"C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN"
processed_folder = os.path.join(dataset_path, "Processed_Images")
original_folder = os.path.join(processed_folder, "original")

# ✅ Create necessary directories
os.makedirs(original_folder, exist_ok=True)

# ✅ Process images while maintaining original size
for folder in ["TRAIN", "VAL", "TEST"]:
    folder_path = os.path.join(dataset_path, folder)

    for img_name in os.listdir(folder_path):
        img_path = os.path.join(folder_path, img_name)

        # ✅ Check if it's a valid image
        if not img_name.lower().endswith(('.jpg', '.png', '.jpeg')):
            continue

        # ✅ Load image in original size
        img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)
        if img is None:
            print(f"⚠️ Skipping {img_name}, unable to read.")
            continue

        # ✅ Save original image without resizing
        save_img(os.path.join(original_folder, img_name), np.expand_dims(img, axis=-1))

print(f"✅ All original images saved in: {original_folder}")
# idhar tak sab sahi hai isme ..original images storeho rahe hai
# Out:
# ✅ All original images saved in: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\original

# %%
# actually iske baad me kuch steps hai jaise overlay folder ...final overlay folder final original folder ..augmentation...train test validation..

# %%
# wo sab steps bypass kiye directly

# %% [markdown]
#  Load Annotations and Perform Augmentation
#  Albumentations Library for augmentation
# Apply same transformation to both image and mask.
# Augmentations:
# Rotation
# Horizontal & Vertical Flipping
# Random Brightness/Contrast
# Elastic Deformation
# Gaussian Noise
# CLAHE (Histogram Equalization)

# %%
import os
import numpy as np
import cv2
import json
import albumentations as A
from tensorflow.keras.preprocessing.image import save_img
# Out:
# c:\users\suraj yadav\appdata\local\programs\python\python38\lib\site-packages\albumentations\__init__.py:13: UserWarning: A new version of Albumentations is available: 2.0.5 (you have 1.4.18). Upgrade using: pip install -U albumentations. To disable automatic update checks, set the environment variable NO_ALBUMENTATIONS_UPDATE to 1.
#   check_for_updates()

# %%
# ✅ Define dataset directories
dataset_path = r"C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN"
processed_folder = os.path.join(dataset_path, "Processed_Images")
original_folder = os.path.join(processed_folder, "final_original")  # Using resized images
mask_folder = os.path.join(processed_folder, "final_overlay")  # Using resized masks
augmented_folder = os.path.join(processed_folder, "augmented")

# ✅ Create necessary directories
os.makedirs(augmented_folder, exist_ok=True)
os.makedirs(os.path.join(augmented_folder, "images"), exist_ok=True)
os.makedirs(os.path.join(augmented_folder, "masks"), exist_ok=True)

# ✅ Load annotation JSON
annotation_file = os.path.join(dataset_path, "annotations_all.json")

with open(annotation_file, "r") as f:
    annotations = json.load(f)

# %%
# ✅ Create augmentation pipeline (Compatible with Albumentations 1.4.18)
augment_pipeline = A.Compose([
    A.HorizontalFlip(p=0.5),
    A.VerticalFlip(p=0.5),
    A.RandomRotate90(p=0.5),
    A.ElasticTransform(alpha=1, sigma=50, alpha_affine=50, p=0.3),
    A.GaussianBlur(blur_limit=(3, 7), p=0.2),
    A.RandomBrightnessContrast(brightness_limit=0.2, contrast_limit=0.2, p=0.2),
    A.CLAHE(clip_limit=2, tile_grid_size=(8, 8), p=0.2),
])
# Out:
# C:\Users\Suraj Yadav\AppData\Local\Temp\ipykernel_10104\4116051105.py:6: UserWarning: Argument 'alpha_affine' is not valid and will be ignored.
#   A.ElasticTransform(alpha=1, sigma=50, alpha_affine=50, p=0.3),

# %%
# ✅ Function to Augment Image-Mask Pairs
def augment_and_save(img, mask, img_name):
    augmented = augment_pipeline(image=img, mask=mask)
    aug_img, aug_mask = augmented["image"], augmented["mask"]

    # ✅ Save Augmented Images
    save_img(os.path.join(augmented_folder, "images", f"aug_{img_name}"), np.expand_dims(aug_img, axis=-1))
    save_img(os.path.join(augmented_folder, "masks", f"aug_{img_name}"), np.expand_dims(aug_mask, axis=-1))

# %%
# ✅ Apply augmentation to all images and masks
for img_name in os.listdir(original_folder):
    img_path = os.path.join(original_folder, img_name)
    mask_path = os.path.join(mask_folder, img_name)

    # ✅ Load image and mask
    img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)
    mask = cv2.imread(mask_path, cv2.IMREAD_GRAYSCALE)

    if img is None or mask is None:
        print(f"⚠️ Skipping {img_name}, unable to read.")
        continue

    # ✅ Perform augmentation and save
    augment_and_save(img, mask, img_name)

print(f"✅ Augmentation complete! Augmented images and masks saved in: {augmented_folder}")
# Out:
# ✅ Augmentation complete! Augmented images and masks saved in: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented

# %%
import matplotlib.pyplot as plt

# ✅ Load a sample image and mask to visualize augmentation
sample_img_name = os.listdir(os.path.join(augmented_folder, "images"))[0]
sample_img_path = os.path.join(augmented_folder, "images", sample_img_name)
sample_mask_path = os.path.join(augmented_folder, "masks", sample_img_name)

# ✅ Read image and mask
sample_img = cv2.imread(sample_img_path, cv2.IMREAD_GRAYSCALE)
sample_mask = cv2.imread(sample_mask_path, cv2.IMREAD_GRAYSCALE)

# ✅ Display the augmented image and mask
plt.figure(figsize=(10, 5))

plt.subplot(1, 2, 1)
plt.imshow(sample_img, cmap="gray")
plt.title("Augmented MRI Image")
plt.axis("off")
  
plt.subplot(1, 2, 2)
plt.imshow(sample_mask, cmap="gray")
plt.title("Augmented Mask")
plt.axis("off")

plt.show()
# Augmentation itna perfect hai no changes needed in this MRIdataOverFinal

# %%
import os
import numpy as np
import shutil
from sklearn.model_selection import train_test_split

# ✅ Define paths for augmented dataset
processed_folder = os.path.join(dataset_path, "Processed_Images")
augmented_images_folder = os.path.join(processed_folder, "augmented/images")
augmented_masks_folder = os.path.join(processed_folder, "augmented/masks")

# ✅ Define train, validation, and test directories
train_folder = os.path.join(processed_folder, "train")
val_folder = os.path.join(processed_folder, "val")
test_folder = os.path.join(processed_folder, "test")

# ✅ Create subdirectories for images and masks
for split in [train_folder, val_folder, test_folder]:
    os.makedirs(os.path.join(split, "images"), exist_ok=True)
    os.makedirs(os.path.join(split, "masks"), exist_ok=True)

# ✅ Get list of augmented image files
image_files = sorted(os.listdir(augmented_images_folder))

# ✅ Ensure masks follow the correct naming pattern
mask_files = sorted(os.listdir(augmented_masks_folder))

# ✅ Filter only matching "aug_" files
image_files = [f for f in image_files if f.startswith("aug_")]
mask_files = [f for f in mask_files if f.startswith("aug_")]

# ✅ Ensure we are only working with matching image-mask pairs
image_files = [f for f in image_files if f in mask_files]

# ✅ Split into train, validation, and test sets (80%-10%-10%)
train_files, test_files = train_test_split(image_files, test_size=0.2, random_state=42)
val_files, test_files = train_test_split(test_files, test_size=0.5, random_state=42)

# ✅ Function to move images and masks into respective folders
def move_files(file_list, src_img_folder, src_mask_folder, dest_folder):
    for file_name in file_list:
        img_src = os.path.join(src_img_folder, file_name)
        mask_src = os.path.join(src_mask_folder, file_name)

        img_dest = os.path.join(dest_folder, "images", file_name)
        mask_dest = os.path.join(dest_folder, "masks", file_name)

        # ✅ Check if files exist before copying
        if not os.path.exists(img_src):
            print(f"⚠️ Missing Image: {img_src}")
            continue
        if not os.path.exists(mask_src):
            print(f"⚠️ Missing Mask: {mask_src}")
            continue

        shutil.copy(img_src, img_dest)
        shutil.copy(mask_src, mask_dest)
        print(f"✅ Copied: {img_src} → {img_dest}")
        print(f"✅ Copied: {mask_src} → {mask_dest}")

# ✅ Move files to respective sets
move_files(train_files, augmented_images_folder, augmented_masks_folder, train_folder)
move_files(val_files, augmented_images_folder, augmented_masks_folder, val_folder)
move_files(test_files, augmented_images_folder, augmented_masks_folder, test_folder)

# ✅ Verify dataset split
train_img_count = len(os.listdir(os.path.join(train_folder, "images")))
val_img_count = len(os.listdir(os.path.join(val_folder, "images")))
test_img_count = len(os.listdir(os.path.join(test_folder, "images")))

print(f"✅ Train dataset: {train_img_count} images")
print(f"✅ Validation dataset: {val_img_count} images")
print(f"✅ Test dataset: {test_img_count} images")

print(f"✅ Dataset split complete! Images saved in:")
print(f"   📂 {train_folder}")
print(f"   📂 {val_folder}")
print(f"   📂 {test_folder}")
# Out:
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/images\aug_y653.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\train\images\aug_y653.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/masks\aug_y653.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\train\masks\aug_y653.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/images\aug_y395.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\train\images\aug_y395.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/masks\aug_y395.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\train\masks\aug_y395.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/images\aug_y406.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\train\images\aug_y406.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/masks\aug_y406.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\train\masks\aug_y406.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/images\aug_y453.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\train\images\aug_y453.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/masks\aug_y453.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\train\masks\aug_y453.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/images\aug_y17.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\train\images\aug_y17.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/masks\aug_y17.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\train\masks\aug_y17.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/images\aug_y231.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\train\images\aug_y231.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/masks\aug_y231.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\train\masks\aug_y231.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/images\aug_y413.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\train\images\aug_y413.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/masks\aug_y413.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\train\masks\aug_y413.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/images\aug_y442.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\train\images\aug_y442.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/masks\aug_y442.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\train\masks\aug_y442.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/images\aug_y495.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\train\images\aug_y495.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/masks\aug_y495.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\train\masks\aug_y495.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/images\aug_y377.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\train\images\aug_y377.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/masks\aug_y377.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\train\masks\aug_y377.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/images\aug_y736.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\train\images\aug_y736.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/masks\aug_y736.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\train\masks\aug_y736.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/images\aug_y218.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\train\images\aug_y218.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/masks\aug_y218.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\train\masks\aug_y218.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/images\aug_y441.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\train\images\aug_y441.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/masks\aug_y441.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\train\masks\aug_y441.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/images\aug_y290.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\train\images\aug_y290.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/masks\aug_y290.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\train\masks\aug_y290.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/images\aug_y693.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\train\images\aug_y693.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/masks\aug_y693.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\train\masks\aug_y693.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/images\aug_y148.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\train\images\aug_y148.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/masks\aug_y148.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\train\masks\aug_y148.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/images\aug_y762.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\train\images\aug_y762.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/masks\aug_y762.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\train\masks\aug_y762.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/images\aug_y646.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\train\images\aug_y646.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/masks\aug_y646.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\train\masks\aug_y646.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/images\aug_y623.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\train\images\aug_y623.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/masks\aug_y623.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\train\masks\aug_y623.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/images\aug_y682.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\train\images\aug_y682.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/masks\aug_y682.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\train\masks\aug_y682.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/images\aug_y574.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\train\images\aug_y574.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/masks\aug_y574.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\train\masks\aug_y574.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/images\aug_y275.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\train\images\aug_y275.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/masks\aug_y275.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\train\masks\aug_y275.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/images\aug_y741.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\train\images\aug_y741.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/masks\aug_y741.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\train\masks\aug_y741.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/images\aug_y72.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\train\images\aug_y72.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/masks\aug_y72.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\train\masks\aug_y72.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/images\aug_y152.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\train\images\aug_y152.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/masks\aug_y152.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\train\masks\aug_y152.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/images\aug_y683.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\train\images\aug_y683.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/masks\aug_y683.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\train\masks\aug_y683.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/images\aug_y668.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\train\images\aug_y668.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/masks\aug_y668.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\train\masks\aug_y668.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/images\aug_y487.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\train\images\aug_y487.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/masks\aug_y487.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\train\masks\aug_y487.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/images\aug_y642.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\train\images\aug_y642.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/masks\aug_y642.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\train\masks\aug_y642.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/images\aug_y497.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\train\images\aug_y497.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/masks\aug_y497.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\train\masks\aug_y497.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/images\aug_y491.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\train\images\aug_y491.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/masks\aug_y491.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\train\masks\aug_y491.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/images\aug_y320.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\train\images\aug_y320.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/masks\aug_y320.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\train\masks\aug_y320.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/images\aug_y627.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\train\images\aug_y627.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/masks\aug_y627.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\train\masks\aug_y627.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/images\aug_y611.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\train\images\aug_y611.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/masks\aug_y611.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\train\masks\aug_y611.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/images\aug_y18.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\train\images\aug_y18.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/masks\aug_y18.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\train\masks\aug_y18.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/images\aug_y685.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\train\images\aug_y685.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/masks\aug_y685.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\train\masks\aug_y685.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/images\aug_y261.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\train\images\aug_y261.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/masks\aug_y261.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\train\masks\aug_y261.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/images\aug_y90.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\train\images\aug_y90.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/masks\aug_y90.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\train\masks\aug_y90.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/images\aug_y678.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\train\images\aug_y678.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/masks\aug_y678.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\train\masks\aug_y678.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/images\aug_y36.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\train\images\aug_y36.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/masks\aug_y36.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\train\masks\aug_y36.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/images\aug_y240.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\train\images\aug_y240.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/masks\aug_y240.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\train\masks\aug_y240.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/images\aug_y160.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\train\images\aug_y160.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/masks\aug_y160.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\train\masks\aug_y160.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/images\aug_y565.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\train\images\aug_y565.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/masks\aug_y565.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\train\masks\aug_y565.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/images\aug_y216.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\train\images\aug_y216.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/masks\aug_y216.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\train\masks\aug_y216.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/images\aug_y138.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\train\images\aug_y138.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/masks\aug_y138.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\train\masks\aug_y138.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/images\aug_y161.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\train\images\aug_y161.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/masks\aug_y161.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\train\masks\aug_y161.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/images\aug_y721.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\train\images\aug_y721.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/masks\aug_y721.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\train\masks\aug_y721.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/images\aug_y418.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\train\images\aug_y418.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/masks\aug_y418.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\train\masks\aug_y418.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/images\aug_y499.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\train\images\aug_y499.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/masks\aug_y499.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\train\masks\aug_y499.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/images\aug_y785.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\train\images\aug_y785.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/masks\aug_y785.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\train\masks\aug_y785.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/images\aug_y22.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\train\images\aug_y22.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/masks\aug_y22.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\train\masks\aug_y22.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/images\aug_y172.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\train\images\aug_y172.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/masks\aug_y172.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\train\masks\aug_y172.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/images\aug_y247.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\train\images\aug_y247.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/masks\aug_y247.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\train\masks\aug_y247.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/images\aug_y246.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\train\images\aug_y246.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/masks\aug_y246.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\train\masks\aug_y246.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/images\aug_y123.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\train\images\aug_y123.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/masks\aug_y123.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\train\masks\aug_y123.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/images\aug_y501.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\train\images\aug_y501.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/masks\aug_y501.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\train\masks\aug_y501.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/images\aug_y272.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\train\images\aug_y272.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/masks\aug_y272.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\train\masks\aug_y272.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/images\aug_y313.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\train\images\aug_y313.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/masks\aug_y313.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\train\masks\aug_y313.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/images\aug_y568.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\train\images\aug_y568.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/masks\aug_y568.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\train\masks\aug_y568.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/images\aug_y757.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\train\images\aug_y757.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/masks\aug_y757.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\train\masks\aug_y757.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/images\aug_y220.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\train\images\aug_y220.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/masks\aug_y220.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\train\masks\aug_y220.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/images\aug_y698.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\train\images\aug_y698.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/masks\aug_y698.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\train\masks\aug_y698.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/images\aug_y379.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\train\images\aug_y379.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/masks\aug_y379.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\train\masks\aug_y379.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/images\aug_y224.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\train\images\aug_y224.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/masks\aug_y224.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\train\masks\aug_y224.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/images\aug_y524.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\train\images\aug_y524.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/masks\aug_y524.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\train\masks\aug_y524.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/images\aug_y103.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\train\images\aug_y103.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/masks\aug_y103.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\train\masks\aug_y103.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/images\aug_y755.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\train\images\aug_y755.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/masks\aug_y755.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\train\masks\aug_y755.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/images\aug_y78.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\train\images\aug_y78.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/masks\aug_y78.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\train\masks\aug_y78.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/images\aug_y164.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\train\images\aug_y164.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/masks\aug_y164.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\train\masks\aug_y164.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/images\aug_y79.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\train\images\aug_y79.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/masks\aug_y79.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\train\masks\aug_y79.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/images\aug_y368.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\train\images\aug_y368.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/masks\aug_y368.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\train\masks\aug_y368.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/images\aug_y229.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\train\images\aug_y229.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/masks\aug_y229.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\train\masks\aug_y229.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/images\aug_y361.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\train\images\aug_y361.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/masks\aug_y361.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\train\masks\aug_y361.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/images\aug_y309.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\train\images\aug_y309.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/masks\aug_y309.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\train\masks\aug_y309.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/images\aug_y297.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\train\images\aug_y297.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/masks\aug_y297.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\train\masks\aug_y297.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/images\aug_y503.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\train\images\aug_y503.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/masks\aug_y503.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\train\masks\aug_y503.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/images\aug_y440.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\train\images\aug_y440.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/masks\aug_y440.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\train\masks\aug_y440.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/images\aug_y217.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\train\images\aug_y217.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/masks\aug_y217.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\train\masks\aug_y217.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/images\aug_y436.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\train\images\aug_y436.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/masks\aug_y436.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\train\masks\aug_y436.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/images\aug_y462.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\train\images\aug_y462.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/masks\aug_y462.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\train\masks\aug_y462.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/images\aug_y57.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\train\images\aug_y57.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/masks\aug_y57.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\train\masks\aug_y57.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/images\aug_y774.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\train\images\aug_y774.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/masks\aug_y774.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\train\masks\aug_y774.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/images\aug_y482.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\train\images\aug_y482.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/masks\aug_y482.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\train\masks\aug_y482.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/images\aug_y135.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\train\images\aug_y135.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/masks\aug_y135.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\train\masks\aug_y135.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/images\aug_y544.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\train\images\aug_y544.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/masks\aug_y544.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\train\masks\aug_y544.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/images\aug_y196.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\train\images\aug_y196.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/masks\aug_y196.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\train\masks\aug_y196.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/images\aug_y408.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\train\images\aug_y408.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/masks\aug_y408.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\train\masks\aug_y408.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/images\aug_y149.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\train\images\aug_y149.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/masks\aug_y149.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\train\masks\aug_y149.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/images\aug_y331.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\train\images\aug_y331.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/masks\aug_y331.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\train\masks\aug_y331.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/images\aug_y53.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\train\images\aug_y53.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/masks\aug_y53.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\train\masks\aug_y53.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/images\aug_y662.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\train\images\aug_y662.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/masks\aug_y662.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\train\masks\aug_y662.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/images\aug_y302.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\train\images\aug_y302.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/masks\aug_y302.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\train\masks\aug_y302.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/images\aug_y29.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\train\images\aug_y29.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/masks\aug_y29.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\train\masks\aug_y29.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/images\aug_y633.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\train\images\aug_y633.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/masks\aug_y633.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\train\masks\aug_y633.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/images\aug_y398.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\train\images\aug_y398.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/masks\aug_y398.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\train\masks\aug_y398.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/images\aug_y12.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\train\images\aug_y12.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/masks\aug_y12.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\train\masks\aug_y12.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/images\aug_y81.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\train\images\aug_y81.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/masks\aug_y81.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\train\masks\aug_y81.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/images\aug_y414.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\train\images\aug_y414.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/masks\aug_y414.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\train\masks\aug_y414.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/images\aug_y419.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\train\images\aug_y419.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/masks\aug_y419.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\train\masks\aug_y419.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/images\aug_y144.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\train\images\aug_y144.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/masks\aug_y144.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\train\masks\aug_y144.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/images\aug_y397.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\train\images\aug_y397.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/masks\aug_y397.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\train\masks\aug_y397.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/images\aug_y76.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\train\images\aug_y76.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/masks\aug_y76.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\train\masks\aug_y76.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/images\aug_y664.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\train\images\aug_y664.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/masks\aug_y664.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\train\masks\aug_y664.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/images\aug_y55.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\train\images\aug_y55.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/masks\aug_y55.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\train\masks\aug_y55.jpg
# ...
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/masks\aug_y66.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\test\masks\aug_y66.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/images\aug_y104.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\test\images\aug_y104.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/masks\aug_y104.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\test\masks\aug_y104.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/images\aug_y88.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\test\images\aug_y88.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/masks\aug_y88.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\test\masks\aug_y88.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/images\aug_y748.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\test\images\aug_y748.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/masks\aug_y748.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\test\masks\aug_y748.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/images\aug_y356.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\test\images\aug_y356.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/masks\aug_y356.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\test\masks\aug_y356.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/images\aug_y479.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\test\images\aug_y479.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/masks\aug_y479.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\test\masks\aug_y479.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/images\aug_y595.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\test\images\aug_y595.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/masks\aug_y595.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\test\masks\aug_y595.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/images\aug_y41.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\test\images\aug_y41.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/masks\aug_y41.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\test\masks\aug_y41.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/images\aug_y673.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\test\images\aug_y673.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/masks\aug_y673.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\test\masks\aug_y673.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/images\aug_y427.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\test\images\aug_y427.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/masks\aug_y427.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\test\masks\aug_y427.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/images\aug_y289.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\test\images\aug_y289.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/masks\aug_y289.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\test\masks\aug_y289.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/images\aug_y724.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\test\images\aug_y724.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/masks\aug_y724.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\test\masks\aug_y724.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/images\aug_y323.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\test\images\aug_y323.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/masks\aug_y323.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\test\masks\aug_y323.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/images\aug_y158.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\test\images\aug_y158.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/masks\aug_y158.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\test\masks\aug_y158.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/images\aug_y717.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\test\images\aug_y717.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/masks\aug_y717.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\test\masks\aug_y717.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/images\aug_y62.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\test\images\aug_y62.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/masks\aug_y62.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\test\masks\aug_y62.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/images\aug_y124.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\test\images\aug_y124.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/masks\aug_y124.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\test\masks\aug_y124.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/images\aug_y719.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\test\images\aug_y719.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/masks\aug_y719.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\test\masks\aug_y719.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/images\aug_y42.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\test\images\aug_y42.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/masks\aug_y42.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\test\masks\aug_y42.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/images\aug_y157.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\test\images\aug_y157.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/masks\aug_y157.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\test\masks\aug_y157.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/images\aug_y647.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\test\images\aug_y647.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/masks\aug_y647.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\test\masks\aug_y647.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/images\aug_y429.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\test\images\aug_y429.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/masks\aug_y429.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\test\masks\aug_y429.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/images\aug_y726.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\test\images\aug_y726.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/masks\aug_y726.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\test\masks\aug_y726.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/images\aug_y31.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\test\images\aug_y31.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/masks\aug_y31.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\test\masks\aug_y31.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/images\aug_y563.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\test\images\aug_y563.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/masks\aug_y563.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\test\masks\aug_y563.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/images\aug_y306.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\test\images\aug_y306.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/masks\aug_y306.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\test\masks\aug_y306.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/images\aug_y635.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\test\images\aug_y635.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/masks\aug_y635.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\test\masks\aug_y635.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/images\aug_y87.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\test\images\aug_y87.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/masks\aug_y87.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\test\masks\aug_y87.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/images\aug_y64.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\test\images\aug_y64.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/masks\aug_y64.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\test\masks\aug_y64.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/images\aug_y223.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\test\images\aug_y223.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/masks\aug_y223.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\test\masks\aug_y223.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/images\aug_y174.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\test\images\aug_y174.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/masks\aug_y174.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\test\masks\aug_y174.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/images\aug_y125.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\test\images\aug_y125.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/masks\aug_y125.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\test\masks\aug_y125.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/images\aug_y749.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\test\images\aug_y749.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/masks\aug_y749.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\test\masks\aug_y749.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/images\aug_y8.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\test\images\aug_y8.jpg
# ✅ Copied: C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\augmented/masks\aug_y8.jpg → C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\test\masks\aug_y8.jpg
# ✅ Train dataset: 640 images
# ✅ Validation dataset: 80 images
# ✅ Test dataset: 81 images
# ✅ Dataset split complete! Images saved in:
#    📂 C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\train
#    📂 C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\val
#    📂 C:\Users\Suraj Yadav\FinalProjectTest\datasetMRI\Br35H-Mask-RCNN\Processed_Images\test

# %%
import os

# ✅ Define dataset directories
train_images_path = os.path.join(processed_folder, "train/images")
train_masks_path = os.path.join(processed_folder, "train/masks")

val_images_path = os.path.join(processed_folder, "val/images")
val_masks_path = os.path.join(processed_folder, "val/masks")

test_images_path = os.path.join(processed_folder, "test/images")
test_masks_path = os.path.join(processed_folder, "test/masks")

# ✅ Count images in each set
print(f"📂 Train: {len(os.listdir(train_images_path))} images")
print(f"📂 Validation: {len(os.listdir(val_images_path))} images")
print(f"📂 Test: {len(os.listdir(test_images_path))} images")
# Out:
# 📂 Train: 640 images
# 📂 Validation: 80 images
# 📂 Test: 81 images

# %%
import os
import numpy as np
import cv2
import tensorflow as tf

# ✅ Define dataset directories
train_images_path = os.path.join(processed_folder, "train/images")
train_masks_path = os.path.join(processed_folder, "train/masks")

val_images_path = os.path.join(processed_folder, "val/images")
val_masks_path = os.path.join(processed_folder, "val/masks")

test_images_path = os.path.join(processed_folder, "test/images")
test_masks_path = os.path.join(processed_folder, "test/masks")

# ✅ Function to Load Images & Masks
def load_data(image_folder, mask_folder):
    image_filenames = sorted(os.listdir(image_folder))
    mask_filenames = sorted(os.listdir(mask_folder))

    images, masks = [], []
    for img_file, mask_file in zip(image_filenames, mask_filenames):
        img_path = os.path.join(image_folder, img_file)
        mask_path = os.path.join(mask_folder, mask_file)

        img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE) / 255.0  # Normalize
        mask = cv2.imread(mask_path, cv2.IMREAD_GRAYSCALE) / 255.0  # Normalize

        img = np.expand_dims(img, axis=-1)  # Add channel dimension
        mask = np.expand_dims(mask, axis=-1)

        images.append(img)
        masks.append(mask)

    return np.array(images), np.array(masks)

# ✅ Load Train, Val, Test Data
X_train, Y_train = load_data(train_images_path, train_masks_path)
X_val, Y_val = load_data(val_images_path, val_masks_path)
X_test, Y_test = load_data(test_images_path, test_masks_path)

# ✅ Print dataset shapes
print(f"✅ Dataset Loaded:")
print(f"   - Train: {X_train.shape}, {Y_train.shape}")
print(f"   - Validation: {X_val.shape}, {Y_val.shape}")
print(f"   - Test: {X_test.shape}, {Y_test.shape}")
# Out:
# ✅ Dataset Loaded:
#    - Train: (640, 256, 256, 1), (640, 256, 256, 1)
#    - Validation: (80, 256, 256, 1), (80, 256, 256, 1)
#    - Test: (81, 256, 256, 1), (81, 256, 256, 1)

# %%
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, Conv2DTranspose, concatenate
from tensorflow.keras.models import Model

# ✅ Function to Build U-Net Model
def build_unet(input_shape=(256, 256, 1)):
    inputs = Input(input_shape)

    # Encoder
    c1 = Conv2D(64, (3, 3), activation='relu', padding='same')(inputs)
    c1 = Conv2D(64, (3, 3), activation='relu', padding='same')(c1)
    p1 = MaxPooling2D((2, 2))(c1)

    c2 = Conv2D(128, (3, 3), activation='relu', padding='same')(p1)
    c2 = Conv2D(128, (3, 3), activation='relu', padding='same')(c2)
    p2 = MaxPooling2D((2, 2))(c2)

    c3 = Conv2D(256, (3, 3), activation='relu', padding='same')(p2)
    c3 = Conv2D(256, (3, 3), activation='relu', padding='same')(c3)
    p3 = MaxPooling2D((2, 2))(c3)

    c4 = Conv2D(512, (3, 3), activation='relu', padding='same')(p3)
    c4 = Conv2D(512, (3, 3), activation='relu', padding='same')(c4)
    p4 = MaxPooling2D((2, 2))(c4)

    # Bottleneck
    c5 = Conv2D(1024, (3, 3), activation='relu', padding='same')(p4)
    c5 = Conv2D(1024, (3, 3), activation='relu', padding='same')(c5)

    # Decoder
    u6 = Conv2DTranspose(512, (2, 2), strides=(2, 2), padding='same')(c5)
    u6 = concatenate([u6, c4])
    c6 = Conv2D(512, (3, 3), activation='relu', padding='same')(u6)
    c6 = Conv2D(512, (3, 3), activation='relu', padding='same')(c6)

    u7 = Conv2DTranspose(256, (2, 2), strides=(2, 2), padding='same')(c6)
    u7 = concatenate([u7, c3])
    c7 = Conv2D(256, (3, 3), activation='relu', padding='same')(u7)
    c7 = Conv2D(256, (3, 3), activation='relu', padding='same')(c7)

    u8 = Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same')(c7)
    u8 = concatenate([u8, c2])
    c8 = Conv2D(128, (3, 3), activation='relu', padding='same')(u8)
    c8 = Conv2D(128, (3, 3), activation='relu', padding='same')(c8)

    u9 = Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same')(c8)
    u9 = concatenate([u9, c1])
    c9 = Conv2D(64, (3, 3), activation='relu', padding='same')(u9)
    c9 = Conv2D(64, (3, 3), activation='relu', padding='same')(c9)

    outputs = Conv2D(1, (1, 1), activation='sigmoid')(c9)

    model = Model(inputs, outputs)
    return model

# ✅ Initialize U-Net Model
unet_model = build_unet()
unet_model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
                   loss="binary_crossentropy",
                   metrics=["accuracy", tf.keras.metrics.MeanIoU(num_classes=2)])

unet_model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 256, 256, 1) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 256, 256, 64) 640         input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 256, 256, 64) 36928       conv2d[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 128, 128, 64) 0           conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 128, 128, 128 73856       max_pooling2d[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 128, 128, 128 147584      conv2d_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 64, 64, 128)  0           conv2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 64, 64, 256)  295168      max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 64, 64, 256)  590080      conv2d_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 32, 32, 256)  0           conv2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 32, 32, 512)  1180160     max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 32, 32, 512)  2359808     conv2d_6[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 16, 16, 512)  0           conv2d_7[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 16, 16, 1024) 4719616     max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 16, 16, 1024) 9438208     conv2d_8[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose (Conv2DTranspo (None, 32, 32, 512)  2097664     conv2d_9[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 32, 32, 1024) 0           conv2d_transpose[0][0]
#                                                                  conv2d_7[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 32, 32, 512)  4719104     concatenate[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 32, 32, 512)  2359808     conv2d_10[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_1 (Conv2DTrans (None, 64, 64, 256)  524544      conv2d_11[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 64, 64, 512)  0           conv2d_transpose_1[0][0]
#                                                                  conv2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 64, 64, 256)  1179904     concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 64, 64, 256)  590080      conv2d_12[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_2 (Conv2DTrans (None, 128, 128, 128 131200      conv2d_13[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 128, 128, 256 0           conv2d_transpose_2[0][0]
#                                                                  conv2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 128, 128, 128 295040      concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 128, 128, 128 147584      conv2d_14[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_3 (Conv2DTrans (None, 256, 256, 64) 32832       conv2d_15[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 256, 256, 128 0           conv2d_transpose_3[0][0]
#                                                                  conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 256, 256, 64) 73792       concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 256, 256, 64) 36928       conv2d_16[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 256, 256, 1)  65          conv2d_17[0][0]
# ==================================================================================================
# Total params: 31,030,593
# Trainable params: 31,030,593
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# ✅ Train U-Net Model
history = unet_model.fit(
    X_train, Y_train,
    validation_data=(X_val, Y_val),
    epochs=20,  # Adjust based on performance
    batch_size=8,  # Adjust based on available memory
    verbose=1
)

print("✅ Model training completed successfully!")3
# Out:
# Epoch 1/20
# 80/80 [==============================] - 1777s 22s/step - loss: 0.4148 - accuracy: 0.1235 - mean_io_u: 0.4901 - val_loss: 0.4158 - val_accuracy: 0.1377 - val_mean_io_u: 0.4891
# Epoch 2/20
# 80/80 [==============================] - 1841s 23s/step - loss: 0.4114 - accuracy: 0.1235 - mean_io_u: 0.4901 - val_loss: 0.4119 - val_accuracy: 0.1377 - val_mean_io_u: 0.4891
# Epoch 3/20
# 80/80 [==============================] - 1958s 24s/step - loss: 0.4090 - accuracy: 0.1235 - mean_io_u: 0.4901 - val_loss: 0.4123 - val_accuracy: 0.1377 - val_mean_io_u: 0.4891
# Epoch 4/20
# 80/80 [==============================] - 2137s 27s/step - loss: 0.4079 - accuracy: 0.1235 - mean_io_u: 0.4901 - val_loss: 0.4124 - val_accuracy: 0.1377 - val_mean_io_u: 0.4891
# Epoch 5/20
# 80/80 [==============================] - 3150s 40s/step - loss: 0.4090 - accuracy: 0.1235 - mean_io_u: 0.4901 - val_loss: 0.4108 - val_accuracy: 0.1377 - val_mean_io_u: 0.4891
# Epoch 6/20
# 80/80 [==============================] - 2463s 31s/step - loss: 0.4073 - accuracy: 0.1235 - mean_io_u: 0.4901 - val_loss: 0.4100 - val_accuracy: 0.1377 - val_mean_io_u: 0.4891
# Epoch 7/20
# 80/80 [==============================] - 1825s 23s/step - loss: 0.4080 - accuracy: 0.1235 - mean_io_u: 0.4901 - val_loss: 0.4100 - val_accuracy: 0.1377 - val_mean_io_u: 0.4891
# Epoch 8/20
# 80/80 [==============================] - 1749s 22s/step - loss: 0.4072 - accuracy: 0.1235 - mean_io_u: 0.4901 - val_loss: 0.4107 - val_accuracy: 0.1377 - val_mean_io_u: 0.4891
# Epoch 9/20
# 80/80 [==============================] - 1908s 24s/step - loss: 0.4069 - accuracy: 0.1235 - mean_io_u: 0.4901 - val_loss: 0.4096 - val_accuracy: 0.1377 - val_mean_io_u: 0.4891
# Epoch 10/20
# 80/80 [==============================] - 1874s 23s/step - loss: 0.4071 - accuracy: 0.1235 - mean_io_u: 0.4901 - val_loss: 0.4095 - val_accuracy: 0.1377 - val_mean_io_u: 0.4891
# Epoch 11/20
# 80/80 [==============================] - 1711s 21s/step - loss: 0.4069 - accuracy: 0.1235 - mean_io_u: 0.4901 - val_loss: 0.4096 - val_accuracy: 0.1377 - val_mean_io_u: 0.4891
# Epoch 12/20
# 80/80 [==============================] - 1701s 21s/step - loss: 0.4069 - accuracy: 0.1235 - mean_io_u: 0.4901 - val_loss: 0.4096 - val_accuracy: 0.1377 - val_mean_io_u: 0.4891
# Epoch 13/20
# 80/80 [==============================] - 1746s 22s/step - loss: 0.4065 - accuracy: 0.1235 - mean_io_u: 0.4901 - val_loss: 0.4094 - val_accuracy: 0.1377 - val_mean_io_u: 0.4891
# Epoch 14/20
# 80/80 [==============================] - 1676s 21s/step - loss: 0.4073 - accuracy: 0.1235 - mean_io_u: 0.4901 - val_loss: 0.4113 - val_accuracy: 0.1377 - val_mean_io_u: 0.4891
# Epoch 15/20
# 80/80 [==============================] - 1713s 21s/step - loss: 0.4073 - accuracy: 0.1235 - mean_io_u: 0.4901 - val_loss: 0.4134 - val_accuracy: 0.1377 - val_mean_io_u: 0.4891
# Epoch 16/20
# 80/80 [==============================] - 1688s 21s/step - loss: 0.4072 - accuracy: 0.1235 - mean_io_u: 0.4901 - val_loss: 0.4090 - val_accuracy: 0.1377 - val_mean_io_u: 0.4891
# Epoch 17/20
# 80/80 [==============================] - 1725s 21s/step - loss: 0.4065 - accuracy: 0.1235 - mean_io_u: 0.4901 - val_loss: 0.4158 - val_accuracy: 0.1376 - val_mean_io_u: 0.4891
# Epoch 18/20
# 80/80 [==============================] - 1882s 24s/step - loss: 0.4066 - accuracy: 0.1235 - mean_io_u: 0.4901 - val_loss: 0.4137 - val_accuracy: 0.1376 - val_mean_io_u: 0.4891
# Epoch 19/20
# 80/80 [==============================] - 1879s 23s/step - loss: 0.4069 - accuracy: 0.1235 - mean_io_u: 0.4901 - val_loss: 0.4101 - val_accuracy: 0.1376 - val_mean_io_u: 0.4891
# Epoch 20/20
# 80/80 [==============================] - 1899s 24s/step - loss: 0.4062 - accuracy: 0.1235 - mean_io_u: 0.4901 - val_loss: 0.4095 - val_accuracy: 0.1377 - val_mean_io_u: 0.4891
# ✅ Model training completed successfully!
